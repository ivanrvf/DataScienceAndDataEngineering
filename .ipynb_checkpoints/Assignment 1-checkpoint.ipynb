# %% [markdown]
# Assignment 1 Part A:
# Analyzing the Employee Earnings Report of 2016 dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
empEarningsDF = pd.read_csv("employeeEarningsReport2016.csv",nrows = 3000, encoding = "ISO-8859-1", header = 0, names = ['Name','DepartmentName','Title','Regular','Retro','Other','Overtime','Injured','Detail','QuinnOrEducationIncentive','TotalEarnings','Postal'])
empEarningsDF.head(100)
# Out:
#                               Name                  DepartmentName  \
# 0                   Abadi,Kidani A            Assessing Department
# 1                 Abasciano,Joseph        Boston Police Department
# 2           Abban,Christopher John          Boston Fire Department
# 3                    Abbasi,Sophia                   Green Academy
# 4          Abbate-Vaughn,Jorgelina            BPS Ellis Elementary
# 5                 Abberton,James P         Public Works Department
# 6            Abbott,Erin Elizabeth                      Hurley K-8
# 7                   Abbott,John R.    BPS Snowden International Hi
# 8                Abbruzzese,Angela             BPS Clap Elementary
# 9                 Abbruzzese,Donna             BPS Clap Elementary
# 10           Abdalkhallaq,Amira N.             BPS O'Bryant School
# 11       Abdal-Khallaq,Musiri Kari                   Green Academy
# 12             Abdal-Khallaq,Naima            BPS Charlestown High
# 13                  Abdelnour,Lisa               BPS Carter Center
# 14                 Abdelrahim,Maha           Boston Public Library
# 15             Abdul-Aziz,Ramadani        Boston Police Department
# 16            Abdur-Rahim,Theodora  HPEC: Com Acd Science & Health
# 17               Abelard,Jean Marc            West Roxbury Academy
# 18          Abellard,Eliphete Jean              Elderly Commission
# 19                 Abelson,Marc A.            BPS Mason Elementary
# 20                 Abichaker,Linda        Boston Police Department
# 21          Abioye,Adedolapo Funke             Higginson/Lewis K-8
# 22               Abo-Sido,Obaida S           BPS Madison Park High
# 23          Aboujaoude,Jocelyne M.         BPS Boston Arts Academy
# 24                Abraham,Caroline               BPS Brighton High
# 25                Abraham,Randolph               BPS Brighton High
# 26               Abraham,Sharon B.         BPS Human Resource Team
# 27            Abrahams,Rafael Noah   UP "Unlocking Potential" Acad
# 28         Abrahamson,Patrick Olaf        Boston Police Department
# 29                Abramoski,Daniel         Margarita Muniz Academy
# ..                             ...                             ...
# 70                     Adams,Clyde           BPS Madison Park High
# 71                  Adams,Daniel J        Boston Police Department
# 72               Adams,Daune Anita              BPS Transportation
# 73                    Adams,Duel B    BPS Alternative Education HS
# 74                 Adams,Eleanor A             Warren/Prescott K-8
# 75               Adams,Elizabeth M    BPS Substitute Teachers/Nurs
# 76              Adams,Frederick C.          Boston Fire Department
# 77                   Adams,Gillian           UP Academy Dorchester
# 78             Adams,Heather Julia                 BPS Fenway High
# 79                   Adams,Jasenta                     Haley Pilot
# 80                 Adams,John Eric          Boston Fire Department
# 81                     Adams,Kwame            Henderson Elementary
# 82                   Adams,Lucille           BPS Holmes Elementary
# 83                   Adams,Natasha  Boston Cntr - Youth & Families
# 84                 Adams,Rebecca E   UP "Unlocking Potential" Acad
# 85                Adams,Terrence K          Boston Fire Department
# 86          Adams-Freeman,Leslie D             BPS Grew Elementary
# 87           Adams-Murphy,Aileen W            BPS Tynan Elementary
# 88                Adario,Anthony J             ASD Human Resources
# 89                Adario,Evelyn T.           BPS Special Education
# 90                   Adarmes,David  Boston Cntr - Youth & Families
# 91  Addaberkane Sr.,Fatima Remaoun            BPS Mckay Elementary
# 92           Adderly,Kadra Trimese        Neighborhood Development
# 93                   Addessa,Rocco             Property Management
# 94                  Adduci,John A.        Boston Police Department
# 95                 Adduci,Joseph M          Boston Fire Department
# 96               Adduci,Vincent R.        Boston Police Department
# 97               Adebayo,Elizabeth            BPS Tynan Elementary
# 98                    Adekoje,John         BPS Boston Arts Academy
# 99               Adinolfi,AnnMarie    BPS Substitute Teachers/Nurs
#
#                             Title       Regular        Retro        Other  \
# 0                Property Officer   $46,291.98           NaN     $300.00
# 1                  Police Officer    $6,933.66           NaN     $850.00
# 2                    Fire Fighter  $103,442.22           NaN     $550.00
# 3            Manager (C) (non-ac)   $18,249.83           NaN          NaN
# 4                         Teacher   $84,410.28           NaN   $1,250.00
# 5        Maint Mech (Carpenter)##   $41,449.16           NaN      $81.00
# 6                         Teacher   $80,413.68           NaN          NaN
# 7                         Teacher   $99,264.10           NaN     $656.04
# 8             Lunch Hour Monitors    $5,000.90           NaN          NaN
# 9             Lunch Hour Monitors      $621.90           NaN          NaN
# 10                        Teacher  $105,500.20           NaN   $5,010.00
# 11                        Teacher   $93,142.59           NaN   $1,346.00
# 12                        Teacher  $105,500.20           NaN      $27.50
# 13               Paraprofessional   $32,463.56           NaN          NaN
# 14                   Library Aide    $1,181.60           NaN          NaN
# 15                 Police Officer   $99,122.67           NaN     $800.00
# 16                        Teacher  $106,200.12           NaN   $2,100.00
# 17                 Staff Asst (B)   $81,717.08           NaN     $550.00
# 18                         Driver   $34,086.59           NaN          NaN
# 19                        Teacher   $90,398.08           NaN          NaN
# 20        Police Clerk And Typist   $46,791.44           NaN          NaN
# 21                        Teacher   $19,810.35           NaN          NaN
# 22                        Teacher   $28,430.75           NaN     $144.00
# 23                          Nurse  $103,584.41           NaN     $500.00
# 24                        Teacher   $63,583.32           NaN   $6,752.78
# 25    Community Field Coordinator   $75,237.12           NaN  $10,242.50
# 26                        Teacher  $107,708.96           NaN   $1,600.00
# 27                        Teacher   $29,827.82           NaN          NaN
# 28                 Police Officer   $80,222.48           NaN     $800.00
# 29           Manager (C) (non-ac)   $92,939.81           NaN          NaN
# ..                            ...           ...          ...          ...
# 70                        Teacher   $63,594.28           NaN  $18,682.81
# 71               Police Detective   $88,101.14   $56,742.25    $6,252.02
# 72                    Cab Monitor   $13,367.10           NaN          NaN
# 73                        Teacher  $106,600.00           NaN     $100.00
# 74  SpEd Support Svcs Coordinator  $104,025.38           NaN          NaN
# 75             Substitute Teacher    $2,040.70           NaN          NaN
# 76                   Fire Fighter  $103,720.30           NaN   $3,039.74
# 77         School Psychologist(1)   $22,879.39           NaN          NaN
# 78              Coord-Manager (B)   $29,182.88           NaN          NaN
# 79            Lunch Hour Monitors    $8,533.85           NaN   $2,067.48
# 80                   Fire Fighter  $102,843.01           NaN     $550.00
# 81                        Teacher   $55,469.45           NaN   $1,162.50
# 82            Lunch Hour Monitors    $8,582.22           NaN          NaN
# 83                   Youth Worker   $47,885.56           NaN          NaN
# 84                        Teacher   $65,577.61           NaN   $1,162.50
# 87          NaN          NaN          NaN                       NaN
# 88          NaN          NaN          NaN                       NaN
# 89          NaN          NaN          NaN                       NaN
# 90      $79.56           NaN          NaN                       NaN
# 91          NaN          NaN          NaN                       NaN
# 92          NaN          NaN          NaN                       NaN
# 93   $3,117.09           NaN          NaN                       NaN
# 94  $22,543.99           NaN          NaN                       NaN
# 95  $17,826.65   $52,914.77           NaN                       NaN
# 96     $655.53           NaN  $19,734.00                 $7,774.13
# 97          NaN          NaN          NaN                       NaN
# 98          NaN          NaN          NaN                       NaN
# 99          NaN          NaN          NaN                       NaN
#
#    TotalEarnings Postal
# 0    $46,591.98    2118
# 1    $97,579.88    2132
# 2   $124,623.25    2132
# 3    $18,249.83    2148
# 4    $85,660.28    2481
# 5    $50,337.63    2127
# 6    $80,413.68    2081
# 7    $99,920.14    2445
# 8     $5,000.90    2125
# 9       $621.90    2125
# 10  $110,510.20    2121
# 11   $94,488.59    2119
# 12  $105,527.70    2121
# 13   $32,463.56    2131
# 14    $1,181.60    2125
# 15  $183,753.99    2119
# 16  $108,300.12    2126
# 17   $82,267.08    2119
# 18   $34,575.60    2126
# 19   $90,398.08    2140
# 20   $46,791.44    2132
# 21   $19,810.35    2124
# 22   $28,574.75    2169
# 23  $104,084.41    2131
# 24   $70,336.10    2135
# 25   $85,479.62    2135
# 26  $109,308.96    2474
# 27   $29,827.82    2143
# 28   $89,369.28    2135
# 29   $92,939.81    2131
# ..           ...    ...
# 70   $82,277.09    2118
# 71  $262,474.70    2131
# 72   $13,367.10    2124
# 73  $106,700.00    2130
# 74  $104,025.38    2127
# 75    $2,040.70    2155
# 76  $118,697.56    2132
# 77   $22,879.39   10512
# 78   $29,182.88    2482
# 79   $10,601.33    2124
# 80  $136,142.19    2124
# 81   $56,631.95    2302
# 82    $8,582.22    2119
# 83   $48,183.89    2124
# 84   $66,740.11    1824
# 85  $117,763.27    2301
# 86   $96,066.96    2718
# 87   $94,859.96    2043
# 88  $108,866.81    2132
# 89  $108,391.07    2132
# 90   $49,355.97    2118
# 91    $8,742.00    2128
# 92   $64,912.90    2124
# 93   $46,183.30    1844
# 94  $134,948.70    2171
# 95  $169,847.01    2171
# 96  $125,087.19    2190
# 97   $62,030.59    2072
# 98   $63,763.81    2121
# 99   $32,906.68    1880
#
# [100 rows x 12 columns]

# %% [markdown]
# Renamed all the column name to maintain a consistant stype of naming. Also, reduced the rows to 3000
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Below is the script to remove the "$ , ( ) \b " signs or in appropriate values from all the financial columns.

# %%
empEarningsDF['Regular'] = pd.Series(empEarningsDF['Regular']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['Retro'] = pd.Series(empEarningsDF['Retro']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['Other'] = pd.Series(empEarningsDF['Other']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['Overtime'] = pd.Series(empEarningsDF['Overtime']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['Injured'] = pd.Series(empEarningsDF['Injured']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['Detail'] = pd.Series(empEarningsDF['Detail']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['QuinnOrEducationIncentive'] = pd.Series(empEarningsDF['QuinnOrEducationIncentive']).str.replace(r'[$,\b\(\)]','')
empEarningsDF['TotalEarnings'] = pd.Series(empEarningsDF['TotalEarnings']).str.replace(r'[$,\b\(\)]','')
empEarningsDF[:50]
# Out:
#                          Name                  DepartmentName  \
# 0              Abadi,Kidani A            Assessing Department
# 1            Abasciano,Joseph        Boston Police Department
# 2      Abban,Christopher John          Boston Fire Department
# 3               Abbasi,Sophia                   Green Academy
# 4     Abbate-Vaughn,Jorgelina            BPS Ellis Elementary
# 5            Abberton,James P         Public Works Department
# 6       Abbott,Erin Elizabeth                      Hurley K-8
# 7              Abbott,John R.    BPS Snowden International Hi
# 8           Abbruzzese,Angela             BPS Clap Elementary
# 9            Abbruzzese,Donna             BPS Clap Elementary
# 10      Abdalkhallaq,Amira N.             BPS O'Bryant School
# 11  Abdal-Khallaq,Musiri Kari                   Green Academy
# 12        Abdal-Khallaq,Naima            BPS Charlestown High
# 13             Abdelnour,Lisa               BPS Carter Center
# 14            Abdelrahim,Maha           Boston Public Library
# 15        Abdul-Aziz,Ramadani        Boston Police Department
# 16       Abdur-Rahim,Theodora  HPEC: Com Acd Science & Health
# 17          Abelard,Jean Marc            West Roxbury Academy
# 18     Abellard,Eliphete Jean              Elderly Commission
# 19            Abelson,Marc A.            BPS Mason Elementary
# 20            Abichaker,Linda        Boston Police Department
# 21     Abioye,Adedolapo Funke             Higginson/Lewis K-8
# 22          Abo-Sido,Obaida S           BPS Madison Park High
# 23     Aboujaoude,Jocelyne M.         BPS Boston Arts Academy
# 24           Abraham,Caroline               BPS Brighton High
# 25           Abraham,Randolph               BPS Brighton High
# 26          Abraham,Sharon B.         BPS Human Resource Team
# 27       Abrahams,Rafael Noah   UP "Unlocking Potential" Acad
# 28    Abrahamson,Patrick Olaf        Boston Police Department
# 29           Abramoski,Daniel         Margarita Muniz Academy
# 30             Abrams,Harriet               BPS Irving Middle
# 31         Abrams,Sarah Gross               BPS Latin Academy
# 32                Abreu,Cesar        Boston Police Department
# 33              Abreu,Iris L.               BPS Brighton High
# 34            Abreu,Julie Ana          Frederick Pilot Middle
# 35             Abreu,Moises J        Boston Police Department
# 36             Abron,Wayne E.          Boston Fire Department
# 37           Abuzeit,Farouqua           Boston Public Library
# 38           Accardi,Patricia    Transportation-Parking Clerk
# 39        Acce Sr.,Jean Denis         BPS Facility Management
# 40  Accime-Plaisimond,Marie J              BPS Transportation
# 41         Accomando,AnnMarie                 BPS Horace Mann
# 42          Ace III,William A         BPS Facility Management
# 43             Ace,Richard K.        Boston Police Department
# 44           Acevedo,Blanca N              BPS Transportation
# 45            Acevedo,Danitza           BPS Taylor Elementary
# 46           Acevedo,Dora Luz        Boston Police Department
# 47            Acevedo,Jasmine                       BTU Pilot
# 48            Acevedo,Johanna      Treasury-Treasury Division
# 49          Acevedo,Rafael W.        Boston Police Department
#
#                             Title     Regular Retro      Other   Overtime  \
# 0                Property Officer   46291.98    NaN    300.00         NaN
# 1                  Police Officer    6933.66    NaN    850.00     205.92
# 2                    Fire Fighter  103442.22    NaN    550.00   15884.53
# 3            Manager (C) (non-ac)   18249.83    NaN        NaN        NaN
# 4                         Teacher   84410.28    NaN   1250.00         NaN
# 5        Maint Mech (Carpenter)##   41449.16    NaN     81.00    8807.47
# 6                         Teacher   80413.68    NaN        NaN        NaN
# 7                         Teacher   99264.10    NaN    656.04         NaN
# 8             Lunch Hour Monitors    5000.90    NaN        NaN        NaN
# 9             Lunch Hour Monitors     621.90    NaN        NaN        NaN
# 10                        Teacher  105500.20    NaN   5010.00         NaN
# 11                        Teacher   93142.59    NaN   1346.00         NaN
# 12                        Teacher  105500.20    NaN     27.50         NaN
# 13               Paraprofessional   32463.56    NaN        NaN        NaN
# 14                   Library Aide    1181.60    NaN        NaN        NaN
# 15                 Police Officer   99122.67    NaN    800.00   25411.32
# 16                        Teacher  106200.12    NaN   2100.00         NaN
# 17                 Staff Asst (B)   81717.08    NaN    550.00         NaN
# 18                         Driver   34086.59    NaN        NaN    489.01
# 19                        Teacher   90398.08    NaN        NaN        NaN
# 20        Police Clerk And Typist   46791.44    NaN        NaN        NaN
# 21                        Teacher   19810.35    NaN        NaN        NaN
# 22                        Teacher   28430.75    NaN    144.00         NaN
# 23                          Nurse  103584.41    NaN    500.00         NaN
# 24                        Teacher   63583.32    NaN   6752.78         NaN
# 25    Community Field Coordinator   75237.12    NaN  10242.50         NaN
# 26                        Teacher  107708.96    NaN   1600.00         NaN
# 27                        Teacher   29827.82    NaN        NaN        NaN
# 28                 Police Officer   80222.48    NaN    800.00    4804.80
# 29           Manager (C) (non-ac)   92939.81    NaN        NaN        NaN
# 30               Paraprofessional   41373.70    NaN     35.00         NaN
# 31                        Teacher   96162.04    NaN   1000.00         NaN
# 32                 Police Officer   85849.67    NaN   6680.12   50193.20
# 33       Library Paraprofessional   33210.10    NaN   3075.00         NaN
# 34                        Teacher   41001.62    NaN    465.00         NaN
# 35                 Police Officer   73019.08    NaN    800.00    7710.63
# 36                   Fire Fighter  103667.51    NaN    550.00   13696.60
# 37      Manager of Youth Services  104006.36    NaN   1501.70     828.29
# 38    Chief Claims Investigator I   70166.42    NaN    488.66     735.00
# 39              Sen Cust C/Nights   44137.52    NaN        NaN   1342.20
# 40                    Cab Monitor   28843.68    NaN        NaN        NaN
# 41                        Teacher   92764.66    NaN        NaN        NaN
# 42                 Jr Cust/Nights   47596.49    NaN        NaN   1141.30
# 43                 Police Officer   82383.86    NaN    800.00    3886.74
# 44             Hot Line Worker HE   20731.94    NaN        NaN        NaN
# 45               Paraprofessional    3367.35    NaN        NaN        NaN
# 46            School Traffic Supv   11347.95    NaN    704.28         NaN
# 47                        Teacher  107620.26    NaN        NaN        NaN
# 48  Prin Admin Asst (Treas/Treas)   62250.74    NaN    150.00     861.51
# 49                 Police Officer   84662.55    NaN   3859.15   18296.84
#
#       Injured     Detail QuinnOrEducationIncentive TotalEarnings Postal
# 0         NaN        NaN                       NaN     46591.98    2118
# 1   74331.86         NaN                 15258.44      97579.88    2132
# 2         NaN   4746.50                        NaN    124623.25    2132
# 3         NaN        NaN                       NaN     18249.83    2148
# 4         NaN        NaN                       NaN     85660.28    2481
# 5         NaN        NaN                       NaN     50337.63    2127
# 6         NaN        NaN                       NaN     80413.68    2081
# 7         NaN        NaN                       NaN     99920.14    2445
# 8         NaN        NaN                       NaN      5000.90    2125
# 9         NaN        NaN                       NaN       621.90    2125
# 10        NaN        NaN                       NaN    110510.20    2121
# 11        NaN        NaN                       NaN     94488.59    2119
# 12        NaN        NaN                       NaN    105527.70    2121
# 13        NaN        NaN                       NaN     32463.56    2131
# 14        NaN        NaN                       NaN      1181.60    2125
# 15        NaN  58420.00                        NaN    183753.99    2119
# 16        NaN        NaN                       NaN    108300.12    2126
# 17        NaN        NaN                       NaN     82267.08    2119
# 18        NaN        NaN                       NaN     34575.60    2126
# 19        NaN        NaN                       NaN     90398.08    2140
# 20        NaN        NaN                       NaN     46791.44    2132
# 21        NaN        NaN                       NaN     19810.35    2124
# 22        NaN        NaN                       NaN     28574.75    2169
# 23        NaN        NaN                       NaN    104084.41    2131
# 24        NaN        NaN                       NaN     70336.10    2135
# 25        NaN        NaN                       NaN     85479.62    2135
# 26        NaN        NaN                       NaN    109308.96    2474
# 27        NaN        NaN                       NaN     29827.82    2143
# 28        NaN   3542.00                        NaN     89369.28    2135
# 29        NaN        NaN                       NaN     92939.81    2131
# 30        NaN        NaN                       NaN     41408.70    2132
# 31        NaN        NaN                       NaN     97162.04    2130
# 32        NaN  40158.00                        NaN    182880.99    2136
# 33        NaN        NaN                       NaN     36285.10    2119
# 34        NaN        NaN                       NaN     41466.62    2116
# 35   1621.31   39882.00                        NaN    123033.02    2136
# 36        NaN        NaN                       NaN    117914.11    2125
# 37        NaN        NaN                       NaN    106336.35    2128
# 38        NaN        NaN                       NaN     71390.08    2081
# 39        NaN        NaN                       NaN     45479.72    2126
# 40        NaN        NaN                       NaN     28843.68    2136
# 41        NaN        NaN                       NaN     92764.66    2026
# 42        NaN        NaN                       NaN     48737.79    2134
# 43        NaN  66654.00                  12338.56     166063.16    2136
# 44        NaN        NaN                       NaN     20731.94    2703
# 45        NaN        NaN                       NaN      3367.35    2151
# 46        NaN        NaN                       NaN     12052.23    2120
# 47        NaN        NaN                       NaN    107620.26    2131
# 48        NaN        NaN                       NaN     63262.25    2136
# 49        NaN  50922.00                        NaN    157740.54    2026

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Below we calculate the sum of null values for each column -

# %%
empEarningsDF.isnull().sum()
# Out:
# Name                            0
# DepartmentName                  0
# Title                           0
# Regular                        73
# Retro                        2944
# Other                        1291
# Overtime                     2131
# Injured                      2819
# Detail                       2678
# QuinnOrEducationIncentive    2850
# TotalEarnings                   0
# Postal                          0
# dtype: int64

# %% [markdown]
# Here we eliminate null values with 0

# %%
empEarningsDF.loc[empEarningsDF.Regular.isnull(),'Regular'] = 0
empEarningsDF.loc[empEarningsDF.Retro.isnull(),'Retro'] = 0
empEarningsDF.loc[empEarningsDF.Other.isnull(),'Other'] = 0
empEarningsDF.loc[empEarningsDF.Overtime.isnull(),'Overtime'] = 0
empEarningsDF.loc[empEarningsDF.Injured.isnull(),'Injured'] = 0
empEarningsDF.loc[empEarningsDF.Detail.isnull(),'Detail'] = 0
empEarningsDF.loc[empEarningsDF.QuinnOrEducationIncentive.isnull(),'QuinnOrEducationIncentive'] = 0
empEarningsDF.isnull().sum()
# Out:
# Name                         0
# DepartmentName               0
# Title                        0
# Regular                      0
# Retro                        0
# Other                        0
# Overtime                     0
# Injured                      0
# Detail                       0
# QuinnOrEducationIncentive    0
# TotalEarnings                0
# Postal                       0
# dtype: int64

# %%
empEarningsDF[:50]
# Out:
#                          Name                  DepartmentName  \
# 0              Abadi,Kidani A            Assessing Department
# 1            Abasciano,Joseph        Boston Police Department
# 2      Abban,Christopher John          Boston Fire Department
# 3               Abbasi,Sophia                   Green Academy
# 4     Abbate-Vaughn,Jorgelina            BPS Ellis Elementary
# 5            Abberton,James P         Public Works Department
# 6       Abbott,Erin Elizabeth                      Hurley K-8
# 7              Abbott,John R.    BPS Snowden International Hi
# 8           Abbruzzese,Angela             BPS Clap Elementary
# 9            Abbruzzese,Donna             BPS Clap Elementary
# 10      Abdalkhallaq,Amira N.             BPS O'Bryant School
# 11  Abdal-Khallaq,Musiri Kari                   Green Academy
# 12        Abdal-Khallaq,Naima            BPS Charlestown High
# 13             Abdelnour,Lisa               BPS Carter Center
# 14            Abdelrahim,Maha           Boston Public Library
# 15        Abdul-Aziz,Ramadani        Boston Police Department
# 16       Abdur-Rahim,Theodora  HPEC: Com Acd Science & Health
# 17          Abelard,Jean Marc            West Roxbury Academy
# 18     Abellard,Eliphete Jean              Elderly Commission
# 19            Abelson,Marc A.            BPS Mason Elementary
# 20            Abichaker,Linda        Boston Police Department
# 21     Abioye,Adedolapo Funke             Higginson/Lewis K-8
# 22          Abo-Sido,Obaida S           BPS Madison Park High
# 23     Aboujaoude,Jocelyne M.         BPS Boston Arts Academy
# 24           Abraham,Caroline               BPS Brighton High
# 25           Abraham,Randolph               BPS Brighton High
# 26          Abraham,Sharon B.         BPS Human Resource Team
# 27       Abrahams,Rafael Noah   UP "Unlocking Potential" Acad
# 28    Abrahamson,Patrick Olaf        Boston Police Department
# 29           Abramoski,Daniel         Margarita Muniz Academy
# 30             Abrams,Harriet               BPS Irving Middle
# 31         Abrams,Sarah Gross               BPS Latin Academy
# 32                Abreu,Cesar        Boston Police Department
# 33              Abreu,Iris L.               BPS Brighton High
# 34            Abreu,Julie Ana          Frederick Pilot Middle
# 35             Abreu,Moises J        Boston Police Department
# 36             Abron,Wayne E.          Boston Fire Department
# 37           Abuzeit,Farouqua           Boston Public Library
# 38           Accardi,Patricia    Transportation-Parking Clerk
# 39        Acce Sr.,Jean Denis         BPS Facility Management
# 40  Accime-Plaisimond,Marie J              BPS Transportation
# 41         Accomando,AnnMarie                 BPS Horace Mann
# 42          Ace III,William A         BPS Facility Management
# 43             Ace,Richard K.        Boston Police Department
# 44           Acevedo,Blanca N              BPS Transportation
# 45            Acevedo,Danitza           BPS Taylor Elementary
# 46           Acevedo,Dora Luz        Boston Police Department
# 47            Acevedo,Jasmine                       BTU Pilot
# 9           0          0                         0       621.90    2125
# 10          0          0                         0    110510.20    2121
# 11          0          0                         0     94488.59    2119
# 12          0          0                         0    105527.70    2121
# 13          0          0                         0     32463.56    2131
# 14          0          0                         0      1181.60    2125
# 15          0  58420.00                          0    183753.99    2119
# 16          0          0                         0    108300.12    2126
# 17          0          0                         0     82267.08    2119
# 18          0          0                         0     34575.60    2126
# 19          0          0                         0     90398.08    2140
# 20          0          0                         0     46791.44    2132
# 21          0          0                         0     19810.35    2124
# 22          0          0                         0     28574.75    2169
# 23          0          0                         0    104084.41    2131
# 24          0          0                         0     70336.10    2135
# 25          0          0                         0     85479.62    2135
# 26          0          0                         0    109308.96    2474
# 27          0          0                         0     29827.82    2143
# 28          0   3542.00                          0     89369.28    2135
# 29          0          0                         0     92939.81    2131
# 30          0          0                         0     41408.70    2132
# 31          0          0                         0     97162.04    2130
# 32          0  40158.00                          0    182880.99    2136
# 33          0          0                         0     36285.10    2119
# 34          0          0                         0     41466.62    2116
# 35   1621.31   39882.00                          0    123033.02    2136
# 36          0          0                         0    117914.11    2125
# 37          0          0                         0    106336.35    2128
# 38          0          0                         0     71390.08    2081
# 39          0          0                         0     45479.72    2126
# 40          0          0                         0     28843.68    2136
# 41          0          0                         0     92764.66    2026
# 42          0          0                         0     48737.79    2134
# 43          0  66654.00                  12338.56     166063.16    2136
# 44          0          0                         0     20731.94    2703
# 45          0          0                         0      3367.35    2151
# 46          0          0                         0     12052.23    2120
# 47          0          0                         0    107620.26    2131
# 48          0          0                         0     63262.25    2136
# 49          0  50922.00                          0    157740.54    2026

# %% [markdown]
# Remove Tabs before and after the strings(In appropriate values) of Name, DepartmentName, Title columns.

# %%
empEarningsDF['Name'] = pd.Series(empEarningsDF['Name']).str.replace(r'[\t]','')
empEarningsDF['DepartmentName'] = pd.Series(empEarningsDF['DepartmentName']).str.replace(r'[\t]','')
empEarningsDF['Title'] = pd.Series(empEarningsDF['Title']).str.replace(r'[\t]','')
empEarningsDF[:50]
# Out:
#                          Name                  DepartmentName  \
# 0              Abadi,Kidani A            Assessing Department
# 1            Abasciano,Joseph        Boston Police Department
# 2      Abban,Christopher John          Boston Fire Department
# 3               Abbasi,Sophia                   Green Academy
# 4     Abbate-Vaughn,Jorgelina            BPS Ellis Elementary
# 5            Abberton,James P         Public Works Department
# 6       Abbott,Erin Elizabeth                      Hurley K-8
# 7              Abbott,John R.    BPS Snowden International Hi
# 8           Abbruzzese,Angela             BPS Clap Elementary
# 9            Abbruzzese,Donna             BPS Clap Elementary
# 10      Abdalkhallaq,Amira N.             BPS O'Bryant School
# 11  Abdal-Khallaq,Musiri Kari                   Green Academy
# 12        Abdal-Khallaq,Naima            BPS Charlestown High
# 13             Abdelnour,Lisa               BPS Carter Center
# 14            Abdelrahim,Maha           Boston Public Library
# 15        Abdul-Aziz,Ramadani        Boston Police Department
# 16       Abdur-Rahim,Theodora  HPEC: Com Acd Science & Health
# 17          Abelard,Jean Marc            West Roxbury Academy
# 18     Abellard,Eliphete Jean              Elderly Commission
# 19            Abelson,Marc A.            BPS Mason Elementary
# 20            Abichaker,Linda        Boston Police Department
# 21     Abioye,Adedolapo Funke             Higginson/Lewis K-8
# 22          Abo-Sido,Obaida S           BPS Madison Park High
# 23     Aboujaoude,Jocelyne M.         BPS Boston Arts Academy
# 24           Abraham,Caroline               BPS Brighton High
# 25           Abraham,Randolph               BPS Brighton High
# 26          Abraham,Sharon B.         BPS Human Resource Team
# 27       Abrahams,Rafael Noah   UP "Unlocking Potential" Acad
# 28    Abrahamson,Patrick Olaf        Boston Police Department
# 29           Abramoski,Daniel         Margarita Muniz Academy
# 30             Abrams,Harriet               BPS Irving Middle
# 31         Abrams,Sarah Gross               BPS Latin Academy
# 32                Abreu,Cesar        Boston Police Department
# 33              Abreu,Iris L.               BPS Brighton High
# 34            Abreu,Julie Ana          Frederick Pilot Middle
# 35             Abreu,Moises J        Boston Police Department
# 36             Abron,Wayne E.          Boston Fire Department
# 37           Abuzeit,Farouqua           Boston Public Library
# 38           Accardi,Patricia    Transportation-Parking Clerk
# 39        Acce Sr.,Jean Denis         BPS Facility Management
# 40  Accime-Plaisimond,Marie J              BPS Transportation
# 41         Accomando,AnnMarie                 BPS Horace Mann
# 42          Ace III,William A         BPS Facility Management
# 43             Ace,Richard K.        Boston Police Department
# 44           Acevedo,Blanca N              BPS Transportation
# 45            Acevedo,Danitza           BPS Taylor Elementary
# 46           Acevedo,Dora Luz        Boston Police Department
# 47            Acevedo,Jasmine                       BTU Pilot
# 48            Acevedo,Johanna      Treasury-Treasury Division
# 49          Acevedo,Rafael W.        Boston Police Department
#
#                             Title     Regular Retro      Other   Overtime  \
# 0                Property Officer   46291.98      0    300.00           0
# 1                  Police Officer    6933.66      0    850.00     205.92
# 2                    Fire Fighter  103442.22      0    550.00   15884.53
# 3            Manager (C) (non-ac)   18249.83      0          0          0
# 4                         Teacher   84410.28      0   1250.00           0
# 5        Maint Mech (Carpenter)##   41449.16      0     81.00    8807.47
# 6                         Teacher   80413.68      0          0          0
# 7                         Teacher   99264.10      0    656.04           0
# 8             Lunch Hour Monitors    5000.90      0          0          0
# 9             Lunch Hour Monitors     621.90      0          0          0
# 10                        Teacher  105500.20      0   5010.00           0
# 11                        Teacher   93142.59      0   1346.00           0
# 12                        Teacher  105500.20      0     27.50           0
# 13               Paraprofessional   32463.56      0          0          0
# 14                   Library Aide    1181.60      0          0          0
# 15                 Police Officer   99122.67      0    800.00   25411.32
# 16                        Teacher  106200.12      0   2100.00           0
# 17                 Staff Asst (B)   81717.08      0    550.00           0
# 18                         Driver   34086.59      0          0    489.01
# 19                        Teacher   90398.08      0          0          0
# 20        Police Clerk And Typist   46791.44      0          0          0
# 21                        Teacher   19810.35      0          0          0
# 22                        Teacher   28430.75      0    144.00           0
# 23                          Nurse  103584.41      0    500.00           0
# 24                        Teacher   63583.32      0   6752.78           0
# 25    Community Field Coordinator   75237.12      0  10242.50           0
# 26                        Teacher  107708.96      0   1600.00           0
# 27                        Teacher   29827.82      0          0          0
# 28                 Police Officer   80222.48      0    800.00    4804.80
# 29           Manager (C) (non-ac)   92939.81      0          0          0
# 30               Paraprofessional   41373.70      0     35.00           0
# 31                        Teacher   96162.04      0   1000.00           0
empEarningsDF['Retro'] = empEarningsDF['Retro'].apply(float)
empEarningsDF['Regular'] = empEarningsDF['Regular'].apply(float)
empEarningsDF['Other'] = empEarningsDF['Other'].apply(float)
empEarningsDF['Overtime'] = empEarningsDF['Overtime'].apply(float)
empEarningsDF['Injured'] = empEarningsDF['Injured'].apply(float)
empEarningsDF['QuinnOrEducationIncentive'] = empEarningsDF['QuinnOrEducationIncentive'].apply(float)
empEarningsDF['Detail'] = empEarningsDF['Detail'].apply(float)
empEarningsDF['TotalEarnings'] = empEarningsDF['TotalEarnings'].apply(float)
empEarningsDF['Postal'] = pd.Series(empEarningsDF['Postal']).astype("category")
empEarningsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
# Name                         3000 non-null object
# DepartmentName               3000 non-null object
# Title                        3000 non-null object
# Regular                      3000 non-null float64
# Retro                        3000 non-null float64
# Other                        3000 non-null float64
# Overtime                     3000 non-null float64
# Injured                      3000 non-null float64
# Detail                       3000 non-null float64
# QuinnOrEducationIncentive    3000 non-null float64
# TotalEarnings                3000 non-null float64
# Postal                       3000 non-null category
# dtypes: category(1), float64(8), object(3)
# memory usage: 275.6+ KB

# %% [markdown]
# ________________________________________________________________________________________________________________________________
#
# Below is the summary statistics of all the columns of dataset:

# %%
empEarningsDF.describe()
# Out:
#             Regular          Retro          Other       Overtime  \
# count    3000.00000    3000.000000    3000.000000    3000.000000
# mean    58741.25194     942.975300    2122.044070    4127.537557
# std     37710.60320    8168.151002    5996.339744   11041.674190
# min         0.00000       0.000000       0.000000       0.000000
# 25%     25502.96250       0.000000       0.000000       0.000000
# 50%     57449.36000       0.000000     150.000000       0.000000
# 75%     93324.08500       0.000000    1692.567500     791.490000
# max    183928.73000  134476.330000  120901.450000  122251.810000
#
#              Injured         Detail  QuinnOrEducationIncentive  TotalEarnings
# count    3000.000000    3000.000000                3000.000000    3000.000000
# mean     1158.376657    2295.344130                 714.278700   70100.088160
# std      8058.650897   10256.663129                3281.938579   51391.313351
# min         0.000000       0.000000                   0.000000       2.500000
# 25%         0.000000       0.000000                   0.000000   28730.170000
# 50%         0.000000       0.000000                   0.000000   63942.585000
# 75%         0.000000       0.000000                   0.000000  103320.545000
# max    125848.560000  121992.000000               30052.100000  351825.500000

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Below is the density distribution plot for each columns:

# %%
sns.distplot(empEarningsDF['Regular'],hist = True, bins = 3)

# %% [markdown]
# The plot above describes the distribution of the regular salary of all the department. It has 3 modes.

# %%
sns.distplot(empEarningsDF['TotalEarnings'],hist = True, bins = 3)

# %% [markdown]
# The plot above describes the distribution of the Total Earnings of all the department. It has 2 modes.

# %%
sns.distplot(empEarningsDF['Retro'],hist = True, bins = 3);

# %% [markdown]
# The plot above describes the distribution of Retro earnings of all the department. It has 0 modes.

# %%
sns.distplot(empEarningsDF['Overtime'],hist = True, bins = 3)

# %% [markdown]
# There are many modes at the beginning of the plot.

# %%
sns.distplot(empEarningsDF['Other'],hist = True, bins = 3)

# %% [markdown]
# There is a single mode for Other earnings distribution plot.

# %%
sns.distplot(empEarningsDF['Injured'],hist = True, bins = 3)

# %%
sns.distplot(empEarningsDF['Detail'],hist = True, bins = 3)

# %% [markdown]
# There is a miinute spike at the beginning of the x axis of Detail earning distribution

# %%
sns.distplot(empEarningsDF['QuinnOrEducationIncentive'],hist = True, bins = 3)

# %% [markdown]
# There are no modes for QuinnOrEducationIncentive distribution

# %% [markdown]
# Box Plot for outliers/anomalies:

# %%
sns.boxplot(x="DepartmentName",y="TotalEarnings", data=empEarningsDF, order=["Assessing Department", "Boston Police Department","Boston Public Library","Traffic Division","Green Academy"])

# %% [markdown]
# The box plot shows that department of Boston Police Department have outliers above the max quartile and Traffic Division have outliers above the max and below the min quartile where as Assessing Department and Boston Public Library and Traffic Division do not have any outliers. The Department of Boston Police has higher Total earnings compared to other departments.
# The Public library has the lowest total salary.

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Scatter Plot for correlations:

# %%
sns.regplot(x="Regular", y="TotalEarnings", data=empEarningsDF.head(1000))

# %% [markdown]
# The scatter plot above describes a positive correlation between the Regular earnings and the Total earnings. There is a linear correlation near the bottom left but as it moves ahead the plots are separated which is not common.
# ________________________________________________________________________________________________________________________________

# %%
sns.regplot(x="Other", y="TotalEarnings", data=empEarningsDF.head(1000))

# %% [markdown]
# There is no linear correlation between Other earnings and total earnings. Most of the spots are accumulated towards the bottom left.

# %%
sns.regplot(x="Overtime", y="TotalEarnings", data=empEarningsDF.head(1000))

# %% [markdown]
# There seems to be maximum accumulation of the spot near the bottom left corner but the plot is not linear. The lower the total earnings the more number of times the overtime amount is paid. The higher the total earnings the overtime earnings is the least.

# %% [markdown]
# Part B:
# Below is the code for web scrapper. I am using this "https://www.trivago.com" website for web scraping.
# 1. List the links is external or internal
# 2. List the http status of these links
# 3. Saving in excel file

# %%
from __future__ import print_function
import urllib3 #  pip install -i https://pypi.anaconda.org/pypi/simple urllib3
import unicodedata
from bs4 import BeautifulSoup, SoupStrainer, Comment
import warnings
import re
import datetime
warnings.filterwarnings('ignore')
url='https://www.trivago.com'
regURL = re.search('[a-z]+\.[a-z]+\.[a-z]+', url)
http = urllib3.PoolManager()
response = http.request('GET',url)

# %% [markdown]
# Code to check if links are external or internal and valid

# %%
soup=BeautifulSoup(response.data, "html.parser")
linkType = "";
status = "";
linkURLDict = {}
i = 0
for link in soup.find_all('a'):
    hrefURL = link.get('href')
    text = link.contents
    try:
        response = http.request('GET',hrefURL)
        status = response.status
        if status == 200:
            status = True
            hrefWebsiteURL = re.search('[a-z]+\.[a-z]+\.[a-z]+', hrefURL)
            if hrefWebsiteURL.group(0) == regURL.group(0):
                linkType = "Internal"
            else:
                linkType = "External"
        else:
            status = False
            linkType = "Cannot identify"
    except:
        status = False
        linkType = "Exception"
    listDict = {}
    listDict.update({"domainType":linkType,"httpRequestStatus":status,"URL":hrefURL,"Associated Text":text,"Timestamp":datetime.datetime.now()})
    linkURLDict.update({i:listDict})
    i+=1
LinkURLDF = pd.DataFrame.from_dict(linkURLDict,orient = 'index')
LinkURLDF
writer = pd.ExcelWriter('WebScraping.xlsx')
LinkURLDF.to_excel(writer,sheet_name='Sheet1',index=True)
writer.save()
